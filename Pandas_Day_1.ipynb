# %% [markdown]
# <a href="https://colab.research.google.com/github/odhiambocalvins200-cloud/Data-Cleaning-and-Visualization/blob/main/Pandas_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to pandas
# Series = A one dimensional array - any type of data, int,str,bol Dataframe

# %%
#importing the library
import pandas as pd

# %%
data = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'city':['New York','San Francisco','Los Angeles'],
    'salary':[50000, 60000, 70000]
}
#data_for_numpy = np.array([1,2,3])
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           city  salary
# 0    Alice   25       New York   50000
# 1      Bob   30  San Francisco   60000
# 2  Charlie   35    Los Angeles   70000

# %%
#peak into the first two rows
df.head(2)
# Out:
#     Name  Age           city  salary
# 0  Alice   25       New York   50000
# 1    Bob   30  San Francisco   60000

# %%
df.tail(2)
# Out:
#       Name  Age           city  salary
# 1      Bob   30  San Francisco   60000
# 2  Charlie   35    Los Angeles   70000

# %%
df.shape
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'city', 'salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   city    3 non-null      object
#  3   salary  3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#         Age   salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0

# %%
df.sample(2)
# Out:
#       Name  Age           city  salary
# 2  Charlie   35    Los Angeles   70000
# 1      Bob   30  San Francisco   60000

# %%
df[['Name' , 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# city      0
# salary    0
# dtype: int64

# %%
#dealing with missing values
df.dropna()#drop
df.fillna(25)#fill
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df[df['Age'] > 30]
# Out:
#       Name  Age         city  salary
# 2  Charlie   35  Los Angeles   70000

# %%
df.sort_values('Age' , ascending=False)
# Out:
#       Name  Age           city  salary
# 2  Charlie   35    Los Angeles   70000
# 1      Bob   30  San Francisco   60000
# 0    Alice   25       New York   50000

# %%
print('Hello Jupyter')
# Out:
# Hello Jupyter

# %%
x = 22
print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
x,y,z ='boy', 'girl', 'adult'
print(x)
print(y)
print(z)
# Out:
# boy
# girl
# adult

# %%
x=y=z='boy'
print(x)
print(y)
print(z)
# Out:
# boy
# boy
# boy

# %%
ice_cream = ['chocolate', 'vanilla', 'strawberry']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# chocolate
# vanilla
# strawberry

# %%
'single quote'
# Out:
# 'single quote'

# %%
"double quote"
# Out:
# 'double quote'

# %%
Multiline = """ThIS IS MY HOME
I LOVE MY HOME"""
print(Multiline)
# Out:
# ThIS IS MY HOME
# I LOVE MY HOME

# %%
a = 'HELLO WORLD'
print(a[3:-5])
# Out:
# LO

# %%
tuple_stoops = (1,5,8,6)
type(tuple_stoops)
# Out:
# tuple

# %%
 daily_wifes_print_log = (1,2,6,7,18,20)

# %%
if 25 > 10:
  print('t'  )
# Out:
# t

# %%
ice_cream = {'chocolate': 'alex', 'vanilla':'big'}
for key, value in ice_cream.items():
  print(key,value)
#
# Out:
# chocolate alex
# vanilla big

# %%
flavors = ['chocolate', 'vanilla', 'strawberry']
toppings = ['sprinkles', 'coconuts', 'cherry']

# %%
for one in flavors:
  for two in toppings:
    print(one, 'topped with',two)
# Out:
# chocolate topped with sprinkles
# chocolate topped with coconuts
# chocolate topped with cherry
# vanilla topped with sprinkles
# vanilla topped with coconuts
# vanilla topped with cherry
# strawberry topped with sprinkles
# strawberry topped with coconuts
# strawberry topped with cherry

# %%
number = 0
while number < 5:
  print(number)
  number = number + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
weight = int(input("Enter your weight in pounds: "))
height = int(input("Enter your height in inches:"))
BMI = (weight * 703) / (height * height)
print(BMI)
# Out:
# Enter your weight in pounds: 12
# Enter your height in inches:30
# 9.373333333333333
